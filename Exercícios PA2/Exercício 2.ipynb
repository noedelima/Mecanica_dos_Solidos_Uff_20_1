# %% [markdown]
# # Exercício PA2-1

# %% [markdown]
# Exercício com data de entrega para 26 de outubro de 2020.
#
#
# Aluno: Noé de Lima Bezerra
#
# <noe_lima@id.uff.br>

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from IPython.display import display, Math, Image
sp.init_printing(use_latex='mathjax',latex_mode='equation*')

# %%
Image("Figuras/PA2-2-0.png")

# %% [markdown]
# # Sistema Estrutural 1

# %%
Image("Figuras/PA2-2-1.png")

# %% [markdown]
# ## a)

# %% [markdown]
# \begin{equation*}
#     V\left(x\right) = V_{A} - 20\cdot x + 20\left<x-3\right> - 50\left<x-5\right>^0
# \end{equation*}
#
# \begin{equation*}
#     M\left(x\right) = V_{A}\cdot x - 10\cdot x^{2} + 10\left<x-3\right>^{2} - 50\left<x-5\right> + M_{A}
# \end{equation*}
#
# \begin{equation*}
#     EI\cdot \theta\left(x\right) = \frac{V_{A}}{2}\cdot x^{2} - \frac{10}{3}\cdot x^{3} + \frac{10}{3}\left<x-3\right>^{3} - 25\left<x-5\right>^{2} + M_{A}\cdot x + C_{1}
# \end{equation*}
#
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{A}}{6}\cdot x^{3} - \frac{10}{12}\cdot x^{4} + \frac{10}{12}\left<x-3\right>^{4} - \frac{25}{3}\left<x-5\right>^{3} + \frac{M_{A}}{2}\cdot x^{2} + C_{1}\cdot x + C_{2}
# \end{equation*}

# %% [markdown]
# ## b)

# %% [markdown]
# * $y(0)=0$
#
# * $\theta(0)=0$
#
# * $y(7)=0$
#
# * $\theta(7)=0$
#
# Temos, portanto, que $C_{1} = C_{2} = 0$.

# %% [markdown]
# \begin{equation*}
#     EI\cdot \theta\left(7\right) = \frac{V_{A}}{2}\cdot 7^{2} - \frac{10}{3}\cdot 7^{3} + \frac{10}{3}\left<7-3\right>^{3} - 25\left<7-5\right>^{2} + M_{A}\cdot 7 = 0
# \end{equation*}
#
# \begin{equation*}
#     EI\cdot y\left(7\right) = \frac{V_{A}}{6}\cdot 7^{3} - \frac{10}{12}\cdot 7^{4} + \frac{10}{12}\left<7-3\right>^{4} - \frac{25}{3}\left<7-5\right>^{3} + \frac{M_{A}}{2}\cdot 7^{2} = 0
# \end{equation*}

# %%
V_A,M_A,EI,x = sp.symbols('V_A,M_A,EI,x')

# %%
theta = sp.Function('theta')(x)
y = sp.Function('y')(x)

# %%
theta = (1/EI) * ((V_A*sp.SingularityFunction(x,0,2)/2) - (10*sp.SingularityFunction(x,0,3)/3) + (10*sp.SingularityFunction(x,3,3)/3) - 25*sp.SingularityFunction(x,5,2) + M_A*sp.SingularityFunction(x,0,1))
y = sp.integrate(theta,x)
display(EI*theta.subs(x,7),EI*y.subs(x,7))
# Out:
#         49⋅V_A
# 7⋅M_A + ────── - 1030
#           2
# 49⋅M_A   343⋅V_A   11125
# ────── + ─────── - ─────
#   2         6        6

# %%
K = sp.Matrix([[7,49/2],[49/2,343/6]])
f = sp.Matrix([[1030],[11125/6]])
display(K.solve(f))
# Out:
# ⎡-67.2448979591836⎤
# ⎢                 ⎥
# ⎣61.2536443148688 ⎦

# %% [markdown]
# Assim, pelas condições de contorno, temos $M_{A} = 67,24~kN\cdot m$ e $V_{A} = 61,25~kN$. Estes valores permitem calcular $V_{B} = 20\times3 + 50 - 61,25 = 48,75~kN$.
#
# Logo, $M_{B} = 67,24 + 61,25\times 7 - 20\times 3\times 5,5 - 50\times 2 = 66,02~kN\cdot m$

# %% [markdown]
# # Sistema Estrutural 2

# %%
Image("Figuras/PA2-2-2.png")

# %% [markdown]
# ## a)

# %% [markdown]
# \begin{equation*}
#     V\left(x\right) = V_{B} - 25\cdot x + 25\left<x-\frac{3}{2}\right> - \frac{75}{2}\left<x-\frac{2}{3}\right>^0
# \end{equation*}
#
# \begin{equation*}
#     M\left(x\right) = V_{B}\cdot x - \frac{25}{2}\cdot x^{2} + \frac{25}{2}\left<x-\frac{3}{2}\right>^{2} - \frac{75}{2}\left<x-\frac{3}{2}\right> - \frac{225}{8}\left<x-\frac{3}{2}\right>^{0}
# \end{equation*}
#
# \begin{equation*}
#     EI\cdot \theta\left(x\right) = \frac{V_{B}}{2}\cdot x^{2} - \frac{25}{6}\cdot x^{3} + \frac{25}{6}\left<x-\frac{3}{2}\right>^{3} - \frac{75}{4}\left<x-\frac{3}{2}\right>^{2} - \frac{225}{8}\left<x-\frac{3}{2}\right> + C_{1}
# \end{equation*}
#
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{B}}{6}\cdot x^{3} - \frac{25}{24}\cdot x^{4} + \frac{25}{24}\left<x-\frac{3}{2}\right>^{4} - \frac{75}{12}\left<x-\frac{3}{2}\right>^{3} - \frac{225}{16}\left<x-\frac{3}{2}\right>^{2} + C_{1}\cdot x + C_{2}
# \end{equation*}

# %% [markdown]
# ## b)

# %% [markdown]
# * $y(0)=0$
#
# * $y(3)=0$
#
# Temos, portanto, que $C_{2} = 0$.

# %%
V_B,C_1 = sp.symbols('V_B,C_1')
M = sp.Function('M')(x)
M = V_B*sp.SingularityFunction(x,0,1) - 25*sp.SingularityFunction(x,0,2)/2 + 25*sp.SingularityFunction(x,3/2,2)/2 - 75*sp.SingularityFunction(x,3/2,1)/2 - 225*sp.SingularityFunction(x,3/2,0)/8
theta = M.integrate(x) + C_1
y = theta.integrate(x)
display(sp.solve(y.subs(x,3),C_1))
# Out:
# [43.9453125 - 1.5⋅V_B]

# %% [markdown]
# $C_1 = 43,95 - 1,5V_{B}$, Logo,
#
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{B}}{6}\cdot x^{3} - \frac{25}{24}\cdot x^{4} + \frac{25}{24}\left<x-\frac{3}{2}\right>^{4} - \frac{75}{12}\left<x-\frac{3}{2}\right>^{3} - \frac{225}{16}\left<x-\frac{3}{2}\right>^{2} + \left(43,95-\frac{3}{2}V_{B}\right)\cdot x
# \end{equation*}

# %% [markdown]
# # Sistema Estrutural 3

# %%
Image("Figuras/PA2-2-3.png")

# %% [markdown]
# ## a)

# %% [markdown]
# \begin{equation*}
#     V\left(x\right) = V_{A} - q\cdot x + q\left<x-\frac{L}{3}\right> - P\left<x-\frac{L}{2}\right>^{0} - q\left<x-\frac{2L}{3}\right>
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     M\left(x\right) = V_{A}\cdot x - \frac{q}{2}\cdot x^{2} + \frac{q}{2}\left<x-\frac{L}{3}\right>^{2} - P\left<x-\frac{L}{2}\right> - \frac{q}{2}\left<x-\frac{2L}{3}\right>^{2} + M_{A}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     EI\cdot\theta\left(x\right) = \frac{V_{A}}{2}\cdot x^{2} - \frac{q}{6}\cdot x^{3} + \frac{q}{6}\left<x-\frac{L}{3}\right>^{3} - \frac{P}{2}\left<x-\frac{L}{2}\right>^{2} - \frac{q}{6}\left<x-\frac{2L}{3}\right>^{3} + M_{A}\cdot x + C_{1}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{A}}{6}\cdot x^{3} - \frac{q}{24}\cdot x^{4} + \frac{q}{24}\left<x-\frac{L}{3}\right>^{4} - \frac{P}{6}\left<x-\frac{L}{2}\right>^{3} - \frac{q}{24}\left<x-\frac{2L}{3}\right>^{4} + \frac{M_{A}}{2}\cdot x^{2} + C_{1}\cdot x + C_{2}
# \end{equation*}

# %% [markdown]
# ## b)

# %% [markdown]
# * $y(0)=0$
#
# * $\theta(0)=0$
#
# * $M(L)=0$
#
# * $y(L)=0$
#
# Temos, portanto, que $C_{1} = C_{2} = 0$.

# %%
q,L,P = sp.symbols('q,L,P')

# %% [markdown]
# Abaixo, segue uma forma de encontrar $M_{A}$ através da condição $M(L)=0$.

# %%
M = V_A*sp.SingularityFunction(x,0,1) - q*sp.SingularityFunction(x,0,2)/2 + q*sp.SingularityFunction(x,L/3,2)/2 - P*sp.SingularityFunction(x,L/2,1) - q*sp.SingularityFunction(x,2*L/3,2)/2 + M_A
display(sp.solve(sp.Eq(M.subs(x,L),0),M_A)[0])
# Out:
#                                     2        2
#                                 2⋅L        L
#      1                   2   q⋅<───>    q⋅<─>
#    L            1   q⋅<L>        3         3
# P⋅<─>  - V_A⋅<L>  + ────── - ──────── + ──────
#    2                  2         2         2

# %% [markdown]
# # Sistema Estrutural 4

# %%
Image("Figuras/PA2-2-4.png")

# %% [markdown]
# ## a)

# %% [markdown]
# \begin{equation*}
#     V\left(x\right) = V_{A} - q\cdot x + q\left<x-\frac{L}{2}\right> - P\left<x-\frac{L}{2}\right>^{0} + V_{B}\left<x-L\right>^{0} - P\left<x-\frac{5L}{4}\right>^{0}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     M\left(x\right) = V_{A}\cdot x - \frac{q}{2}\cdot x^{2} + \frac{q}{2}\left<x-\frac{L}{2}\right>^{2} - P\left<x-\frac{L}{2}\right> + V_{B}\left<x-L\right> - P\left<x-\frac{5L}{4}\right> + M_{A}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     EI\cdot\theta\left(x\right) = \frac{V_{A}}{2}\cdot x^{2} - \frac{q}{6}\cdot x^{3} + \frac{q}{6}\left<x-\frac{L}{2}\right>^{3} - \frac{P}{2}\left<x-\frac{L}{2}\right>^{2} + \frac{V_{B}}{2}\left<x-L\right>^{2} - \frac{P}{2}\left<x-\frac{5L}{4}\right>^{2} + M_{A}\cdot x + C_{1}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{A}}{6}\cdot x^{3} - \frac{q}{24}\cdot x^{4} + \frac{q}{24}\left<x-\frac{L}{2}\right>^{4} - \frac{P}{6}\left<x-\frac{L}{2}\right>^{3} + \frac{V_{B}}{6}\left<x-L\right>^{3} - \frac{P}{6}\left<x-\frac{5L}{4}\right>^{3} + \frac{M_{A}}{2}\cdot x^{2} + C_{1}\cdot x + C_{2}
# \end{equation*}

# %% [markdown]
# ## b)

# %% [markdown]
# * $y(0)=0$
#
# * $\theta(0)=0$
#
# * $y(L)=0$
#
# * $M\left(\frac{3L}{2}\right)=0$
#
# * $y\left(\frac{3L}{2}\right)=0$
#
# Temos, portanto, que $C_{1} = C_{2} = 0$.

# %% [markdown]
# \begin{equation*}
#     EI\cdot y\left(x\right) = \frac{V_{A}}{6}\cdot x^{3} - \frac{q}{24}\cdot x^{4} + \frac{q}{24}\left<x-\frac{L}{2}\right>^{4} - \frac{P}{6}\left<x-\frac{L}{2}\right>^{3} + \frac{V_{B}}{6}\left<x-L\right>^{3} - \frac{P}{6}\left<x-\frac{5L}{4}\right>^{3} + \frac{M_{A}}{2}\cdot x^{2}
# \end{equation*}
